# %%
import os
import pandas as pd
import datetime
import glob
from google.colab import files
import numpy as np
import re
#import dask.dataframe as dd
#from dask.diagnostics import ProgressBar
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
i2m = list(zip(range(1,13), ['Gener','Febrer','Marc','Abril','Maig','Juny','Juliol','Agost','Setembre','Octubre','Novembre','Desembre']))
for year in range(2023, 2019, -1):
    for month, month_name in i2m:
        if (month > 5) and (year>2023): continue
        #Descarrega arxius de la web de Bicing
        os.system(f'curl -L -o "{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z" "https://opendata-ajuntament.barcelona.cat/resources/bcn/BicingBCN/{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z"')
        #Extreu fitxers del format 7z
        os.system(f"7z x '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")
        #Elimina l'arxiu comprimit
        os.system(f"rm '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")

# %%
import os
import re
fileList = os.listdir()

# Regex que coincideix amb: 2020_02_Febrer_BicingNou_ESTACIONS.csv
pattern = re.compile(r"^(202[0-3])_\d{2}_[A-Za-zÀ-ÿ]+_BicingNou_ESTACIONS\.csv$")

listCsv = [file for file in fileList if file.endswith(".csv") and pattern.match(file)]
listCsv = sorted(listCsv)
listCsv
# Out:
# ['2020_01_Gener_BicingNou_ESTACIONS.csv',
#  '2020_02_Febrer_BicingNou_ESTACIONS.csv',
#  '2020_03_Marc_BicingNou_ESTACIONS.csv',
#  '2020_04_Abril_BicingNou_ESTACIONS.csv',
#  '2020_05_Maig_BicingNou_ESTACIONS.csv',
#  '2020_06_Juny_BicingNou_ESTACIONS.csv',
#  '2020_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2020_08_Agost_BicingNou_ESTACIONS.csv',
#  '2020_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2020_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2020_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2020_12_Desembre_BicingNou_ESTACIONS.csv',
#  '2021_01_Gener_BicingNou_ESTACIONS.csv',
#  '2021_02_Febrer_BicingNou_ESTACIONS.csv',
#  '2021_03_Març_BicingNou_ESTACIONS.csv',
#  '2021_04_Abril_BicingNou_ESTACIONS.csv',
#  '2021_05_Maig_BicingNou_ESTACIONS.csv',
#  '2021_06_Juny_BicingNou_ESTACIONS.csv',
#  '2021_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2021_08_Agost_BicingNou_ESTACIONS.csv',
#  '2021_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2021_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2021_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2021_12_Desembre_BicingNou_ESTACIONS.csv',
#  '2022_01_Gener_BicingNou_ESTACIONS.csv',
#  '2022_02_Febrer_BicingNou_ESTACIONS.csv',
#  '2022_03_Març_BicingNou_ESTACIONS.csv',
#  '2022_04_Abril_BicingNou_ESTACIONS.csv',
#  '2022_05_Maig_BicingNou_ESTACIONS.csv',
#  '2022_06_Juny_BicingNou_ESTACIONS.csv',
#  '2022_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2022_08_Agost_BicingNou_ESTACIONS.csv',
#  '2022_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2022_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2022_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2022_12_Desembre_BicingNou_ESTACIONS.csv',
#  '2023_01_Gener_BicingNou_ESTACIONS.csv',
#  '2023_02_Febrer_BicingNou_ESTACIONS.csv',
#  '2023_03_Marc_BicingNou_ESTACIONS.csv',
#  '2023_04_Abril_BicingNou_ESTACIONS.csv',
#  '2023_05_Maig_BicingNou_ESTACIONS.csv',
#  '2023_06_Juny_BicingNou_ESTACIONS.csv',
#  '2023_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2023_08_Agost_BicingNou_ESTACIONS.csv',
#  '2023_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2023_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2023_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2023_12_Desembre_BicingNou_ESTACIONS.csv']

# %%
# !pip install dask
# Out:
# Collecting dask
#   Downloading dask-2025.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask) (24.2)
# Collecting partd>=1.4.0 (from dask)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask) (1.0.0)
# Collecting importlib_metadata>=4.13.0 (from dask)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask) (3.21.0)
# Collecting locket (from partd>=1.4.0->dask)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading dask-2025.3.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.1 MB/s eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: locket, importlib_metadata, partd, dask
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
# Successfully installed dask-2025.3.0 importlib_metadata-8.6.1 locket-1.0.0 partd-1.4.2

# %%
import dask.dataframe as dd
import os
from dask.diagnostics import ProgressBar

def transform_bike_data_dask(listCsv):
    dfs = []
    for file in listCsv:
        print(f"Loading {file}...")
        ddf = dd.read_csv(
            file,
            dtype={
                "station_id": str,
                "last_reported": "float64",
                "is_returning": "object",
                "status": "object"  # ← Añadido para evitar error

            },
            assume_missing=True
        )
        ddf["source_file"] = file  # opcional, para trazabilidad
        dfs.append(ddf)

    # Unir todos los CSVs en un único Dask DataFrame
    ddf = dd.concat(dfs, axis=0)

    # Procesamiento
    ddf["last_updated"] = dd.to_datetime(ddf["last_updated"], unit="s")
    # Usar 'h' en lugar de 'H' para evitar la advertencia futura
    ddf["last_updated_hour"] = ddf["last_updated"].dt.floor("h")

    ddf["total_docks"] = ddf["num_bikes_available"] + ddf["num_docks_available"]
    ddf["percentage_docks_available"] = ddf["num_docks_available"] / ddf["total_docks"]

    # Agrupar por estación y hora
    grouped = (
        ddf.groupby(["station_id", "last_updated_hour"])
        .mean(numeric_only=True)
        .reset_index()
    )

    # Extraer componentes temporales
    grouped["year"] = grouped["last_updated_hour"].dt.year
    grouped["month"] = grouped["last_updated_hour"].dt.month
    grouped["day"] = grouped["last_updated_hour"].dt.day
    grouped["hour"] = grouped["last_updated_hour"].dt.hour

    # Forzar el cómputo para trabajar con Pandas y evitar problemas de índice
    with ProgressBar():
        grouped_pd = grouped.compute()

    # Ordenar por station_id y last_updated_hour para aplicar shift correctamente
    grouped_pd = grouped_pd.sort_values(["station_id", "last_updated_hour"]).reset_index(drop=True)

    # Calcular ctx-0 (valor actual)
    grouped_pd["ctx-0"] = grouped_pd["percentage_docks_available"]

    # Calcular ctx-1 a ctx-4 de forma continua por station_id
    for i in range(1, 5):
        grouped_pd[f"ctx-{i}"] = (
            grouped_pd.groupby("station_id")["percentage_docks_available"]
            .shift(i)
            .fillna(0)
        )

    # Seleccionar columnas finales
    # Seleccionar columnas finales
    final_cols = [
        "station_id", "year", "month", "day", "hour",
        "ctx-4", "ctx-3", "ctx-2", "ctx-1", "ctx-0"
    ]

    final_df = grouped_pd[final_cols]

    return final_df

# %% [markdown]
# 1. Carregar tots els fitxers CSV en dataframes i, a continuació, calcular la mitjana per hora de les variables (fem la mitjana per a cada estació station_id i hora), intentem usar Dask però no és l'òptim per a nosaltres. A més afegim la columna de mes (month_num) i any (year) per quan unim tots els diferents mesos saber d'on provenien les observacions, i les variables 'ctx-4', 'ctx-3', 'ctx-2', 'ctx-1', 'percentage_docks_available', 'percentage_bikes_mech', 'percentage_bikes_e'.

# %%
listCsv = sorted(listCsv)

df_result = transform_bike_data_dask(listCsv)
# Out:
# Loading 2020_01_Gener_BicingNou_ESTACIONS.csv...
# Loading 2020_02_Febrer_BicingNou_ESTACIONS.csv...
# Loading 2020_03_Marc_BicingNou_ESTACIONS.csv...
# Loading 2020_04_Abril_BicingNou_ESTACIONS.csv...
# Loading 2020_05_Maig_BicingNou_ESTACIONS.csv...
# Loading 2020_06_Juny_BicingNou_ESTACIONS.csv...
# Loading 2020_07_Juliol_BicingNou_ESTACIONS.csv...
# Loading 2020_08_Agost_BicingNou_ESTACIONS.csv...
# Loading 2020_09_Setembre_BicingNou_ESTACIONS.csv...
# Loading 2020_10_Octubre_BicingNou_ESTACIONS.csv...
# Loading 2020_11_Novembre_BicingNou_ESTACIONS.csv...
# Loading 2020_12_Desembre_BicingNou_ESTACIONS.csv...
# Loading 2021_01_Gener_BicingNou_ESTACIONS.csv...
# Loading 2021_02_Febrer_BicingNou_ESTACIONS.csv...
# Loading 2021_03_Març_BicingNou_ESTACIONS.csv...
# Loading 2021_04_Abril_BicingNou_ESTACIONS.csv...
# Loading 2021_05_Maig_BicingNou_ESTACIONS.csv...
# Loading 2021_06_Juny_BicingNou_ESTACIONS.csv...
# Loading 2021_07_Juliol_BicingNou_ESTACIONS.csv...
# Loading 2021_08_Agost_BicingNou_ESTACIONS.csv...
# Loading 2021_09_Setembre_BicingNou_ESTACIONS.csv...
# Loading 2021_10_Octubre_BicingNou_ESTACIONS.csv...
# Loading 2021_11_Novembre_BicingNou_ESTACIONS.csv...
# Loading 2021_12_Desembre_BicingNou_ESTACIONS.csv...
# Loading 2022_01_Gener_BicingNou_ESTACIONS.csv...
# Loading 2022_02_Febrer_BicingNou_ESTACIONS.csv...
# Loading 2022_03_Març_BicingNou_ESTACIONS.csv...
# Loading 2022_04_Abril_BicingNou_ESTACIONS.csv...
# Loading 2022_05_Maig_BicingNou_ESTACIONS.csv...
# Loading 2022_06_Juny_BicingNou_ESTACIONS.csv...
# Loading 2022_07_Juliol_BicingNou_ESTACIONS.csv...
# Loading 2022_08_Agost_BicingNou_ESTACIONS.csv...
# Loading 2022_09_Setembre_BicingNou_ESTACIONS.csv...
# Loading 2022_10_Octubre_BicingNou_ESTACIONS.csv...
# Loading 2022_11_Novembre_BicingNou_ESTACIONS.csv...
# Loading 2022_12_Desembre_BicingNou_ESTACIONS.csv...
# Loading 2023_01_Gener_BicingNou_ESTACIONS.csv...
# Loading 2023_02_Febrer_BicingNou_ESTACIONS.csv...
# Loading 2023_03_Marc_BicingNou_ESTACIONS.csv...
# Loading 2023_04_Abril_BicingNou_ESTACIONS.csv...
# Loading 2023_05_Maig_BicingNou_ESTACIONS.csv...
# Loading 2023_06_Juny_BicingNou_ESTACIONS.csv...
# Loading 2023_07_Juliol_BicingNou_ESTACIONS.csv...
# Loading 2023_08_Agost_BicingNou_ESTACIONS.csv...
# Loading 2023_09_Setembre_BicingNou_ESTACIONS.csv...
# Loading 2023_10_Octubre_BicingNou_ESTACIONS.csv...
# Loading 2023_11_Novembre_BicingNou_ESTACIONS.csv...
# Loading 2023_12_Desembre_BicingNou_ESTACIONS.csv...
# [#######################                 ] | 59% Completed | 157.69 s
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:77: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# [#############################           ] | 73% Completed | 167.33 s
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:77: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# [########################################] | 100% Completed | 196.84 s

# %%
df_result.to_csv("df_result_with_year_2020_2023_v2.csv", index=False)

# %%
df_result
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                 1  2019.0   12.0  31.0  23.0  0.000000  0.000000  0.000000
# 1                 1  2020.0    1.0   1.0   0.0  0.000000  0.000000  0.000000
# 2                 1  2020.0    1.0   1.0   1.0  0.000000  0.000000  0.509470
# 3                 1  2020.0    1.0   1.0   2.0  0.000000  0.509470  0.469697
# 4                 1  2020.0    1.0   1.0   3.0  0.509470  0.469697  0.407343
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 16799500         99  2023.0   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 16799501         99  2023.0   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 16799502         99  2023.0   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 16799503         99  2023.0   12.0  31.0  23.0  0.041667  0.016667  0.045833
# 16799504       <NA>     NaN    NaN   NaN   NaN  0.000000  0.000000  0.000000
#
#              ctx-1     ctx-0
# 0         0.000000  0.509470
# 1         0.509470  0.469697
# 2         0.469697  0.407343
# 3         0.407343  0.359504
# 4         0.359504  0.291667
# ...            ...       ...
# 16799500  0.041667  0.016667
# 16799501  0.016667  0.045833
# 16799502  0.045833  0.000000
# 16799503  0.000000  0.000000
# 16799504  0.000000       NaN
#
# [16799505 rows x 10 columns]

# %%
df_result = df_result.dropna()

# %%
df_result
# Out:
#          station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                 1  2019.0   12.0  31.0  23.0  0.000000  0.000000  0.000000
# 1                 1  2020.0    1.0   1.0   0.0  0.000000  0.000000  0.000000
# 2                 1  2020.0    1.0   1.0   1.0  0.000000  0.000000  0.509470
# 3                 1  2020.0    1.0   1.0   2.0  0.000000  0.509470  0.469697
# 4                 1  2020.0    1.0   1.0   3.0  0.509470  0.469697  0.407343
# ...             ...     ...    ...   ...   ...       ...       ...       ...
# 16799499         99  2023.0   12.0  31.0  19.0  0.320175  0.144737  0.208333
# 16799500         99  2023.0   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 16799501         99  2023.0   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 16799502         99  2023.0   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 16799503         99  2023.0   12.0  31.0  23.0  0.041667  0.016667  0.045833
#
#              ctx-1     ctx-0
# 0         0.000000  0.509470
# 1         0.509470  0.469697
# 2         0.469697  0.407343
# 3         0.407343  0.359504
# 4         0.359504  0.291667
# ...            ...       ...
# 16799499  0.150000  0.041667
# 16799500  0.041667  0.016667
# 16799501  0.016667  0.045833
# 16799502  0.045833  0.000000
# 16799503  0.000000  0.000000
#
# [16789382 rows x 10 columns]

# %% [markdown]
# # LOAD BIG DATASET, NAS AND CREATE X,Y FOR TRAIN

# %%
#https://www.kaggle.com/competitions/2025-bike-availability-prediction/data?select=metadata_sample_submission_2025.csv

# %%
import pandas as pd

df = pd.read_csv('df_result_with_year_2020_2023_v2.csv')

print(df)
# Out:
#           station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                  1  2019.0   12.0  31.0  23.0  0.000000  0.000000  0.000000
# 1                  1  2020.0    1.0   1.0   0.0  0.000000  0.000000  0.000000
# 2                  1  2020.0    1.0   1.0   1.0  0.000000  0.000000  0.509470
# 3                  1  2020.0    1.0   1.0   2.0  0.000000  0.509470  0.469697
# 4                  1  2020.0    1.0   1.0   3.0  0.509470  0.469697  0.407343
# ...              ...     ...    ...   ...   ...       ...       ...       ...
# 16789377          99  2023.0   12.0  31.0  19.0  0.320175  0.144737  0.208333
# 16789378          99  2023.0   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 16789379          99  2023.0   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 16789380          99  2023.0   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 16789381          99  2023.0   12.0  31.0  23.0  0.041667  0.016667  0.045833
#
#              ctx-1     ctx-0
# 0         0.000000  0.509470
# 1         0.509470  0.469697
# 2         0.469697  0.407343
# 3         0.407343  0.359504
# 4         0.359504  0.291667
# ...            ...       ...
# 16789377  0.150000  0.041667
# 16789378  0.041667  0.016667
# 16789379  0.016667  0.045833
# 16789380  0.045833  0.000000
# 16789381  0.000000  0.000000
#
# [16789382 rows x 10 columns]

# %%
# Contar valores NaN por columna
print("Valores NaN por columna:")
print(df.isnull().sum())

# Contar valores 0 por columna (ten en cuenta que para columnas numéricas)
print("\nValores 0 por columna:")
print((df == 0).sum())

# Eliminar filas con NaNs
df = df.dropna()

# Verificar que se han eliminado los NaNs
print("\nValores NaN por columna después de limpiar:")
print(df.isnull().sum())
# Out:
# Valores NaN por columna:
# station_id    0
# year          0
# month         0
# day           0
# hour          0
# ctx-4         0
# ctx-3         0
# ctx-2         0
# ctx-1         0
# ctx-0         0
# dtype: int64
#
# Valores 0 por columna:
# station_id         0
# year               0
# month              0
# day                0
# hour          693944
# ctx-4          94750
# ctx-3          93904
# ctx-2          93032
# ctx-1          92127
# ctx-0          91123
# dtype: int64
#
# Valores NaN por columna después de limpiar:
# station_id    0
# year          0
# month         0
# day           0
# hour          0
# ctx-4         0
# ctx-3         0
# ctx-2         0
# ctx-1         0
# ctx-0         0
# dtype: int64

# %%
df=df[df['year']>=2021]

# %%
X_train = df
X_train.columns
# Out:
# Index(['station_id', 'year', 'month', 'day', 'hour', 'ctx-4', 'ctx-3', 'ctx-2',
#        'ctx-1', 'ctx-0'],
#       dtype='object')

# %% [markdown]
# # LOAD X TEST

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "metadata_sample_submission_2025.csv"

# Carga del CSV en un DataFrame
X_test = pd.read_csv(ruta_csv)

# Visualizar las primeras filas
print(X_test.head())
# Out:
#    index  station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1
# 0      0           1      6    1     3  0.490942  0.378623  0.324275  0.311594
# 1      1           1      6    1     8  0.271739  0.311594  0.346014  0.394928
# 2      2           1      6    1    13  0.538043  0.650362  0.697464  0.721014
# 3      3           1      6    1    18  0.789855  0.800725  0.791667  0.807971
# 4      4           1      6    1    23  0.860507  0.871377  0.817029  0.793478

# %%
X_test['year'] = 2024

# %%
X_test
# Out:
#          index  station_id  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0            0           1      6    1     3  0.490942  0.378623  0.324275
# 1            1           1      6    1     8  0.271739  0.311594  0.346014
# 2            2           1      6    1    13  0.538043  0.650362  0.697464
# 3            3           1      6    1    18  0.789855  0.800725  0.791667
# 4            4           1      6    1    23  0.860507  0.871377  0.817029
# ...        ...         ...    ...  ...   ...       ...       ...       ...
# 401506  401506         496     12   31     2  0.865741  0.643519  0.597222
# 401507  401507         496     12   31     7  1.000000  0.388889  0.375000
# 401508  401508         496     12   31    12  0.310185  0.337963  0.402778
# 401509  401509         496     12   31    17  0.462963  0.564815  0.629630
# 401510  401510         496     12   31    22  0.467593  0.361111  0.546296
#
#            ctx-1  year
# 0       0.311594  2024
# 1       0.394928  2024
# 2       0.721014  2024
# 3       0.807971  2024
# 4       0.793478  2024
# ...          ...   ...
# 401506  0.921296  2024
# 401507  0.407407  2024
# 401508  0.495370  2024
# 401509  0.583333  2024
# 401510  0.550926  2024
#
# [401511 rows x 10 columns]

# %% [markdown]
# # WEATHER DATA

# %% [markdown]
# ## Load data

# %%
import pandas as pd

meteo = pd.read_csv('Informacio_Estacions_Bicing_2025.csv')

meteo = meteo[['station_id', 'lat', 'lon', 'altitude']]

# %%
df_merged = pd.merge(df, meteo, on=['station_id'], how='inner')
df_merged
# Out:
#          station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0                 1  2021      1    1     0  0.043478  0.045290  0.050725
# 1                 1  2021      1    1     1  0.045290  0.050725  0.063406
# 2                 1  2021      1    1     2  0.050725  0.063406  0.119565
# 3                 1  2021      1    1     3  0.063406  0.119565  0.108696
# 4                 1  2021      1    1     4  0.119565  0.108696  0.108696
# ...             ...   ...    ...  ...   ...       ...       ...       ...
# 8748579          99  2022     12   31    19  0.468254  0.657738  0.615079
# 8748580          99  2022     12   31    20  0.657738  0.615079  0.686508
# 8748581          99  2022     12   31    21  0.615079  0.686508  0.603175
# 8748582          99  2022     12   31    22  0.686508  0.603175  0.571429
# 8748583          99  2022     12   31    23  0.603175  0.571429  0.567460
#
#             ctx-1     ctx-0        lat       lon  altitude
# 0        0.063406  0.119565  41.397978  2.180107      16.0
# 1        0.119565  0.108696  41.397978  2.180107      16.0
# 2        0.108696  0.108696  41.397978  2.180107      16.0
# 3        0.108696  0.108696  41.397978  2.180107      16.0
# 4        0.108696  0.108696  41.397978  2.180107      16.0
# ...           ...       ...        ...       ...       ...
# 8748579  0.686508  0.603175  41.380822  2.141539      30.0
# 8748580  0.603175  0.571429  41.380822  2.141539      30.0
# 8748581  0.571429  0.567460  41.380822  2.141539      30.0
# 8748582  0.567460  0.531746  41.380822  2.141539      30.0
# 8748583  0.531746  0.460317  41.380822  2.141539      30.0
#
# [8748584 rows x 13 columns]

# %%
stations = df_merged[["station_id", "lat", "lon"]].drop_duplicates()
stations
# Out:
#          station_id        lat       lon
# 0                 1  41.397978  2.180107
# 17392            10  41.346775  2.143623
# 34827           100  41.379363  2.143868
# 52240           101  41.392878  2.143411
# 69663           102  41.392567  2.142217
# ...             ...        ...       ...
# 8665623          95  41.376395  2.147327
# 8683062          96  41.374109  2.148199
# 8696271          97  41.377961  2.145049
# 8713705          98  41.380607  2.140863
# 8731144          99  41.380822  2.141539
#
# [505 rows x 3 columns]

# %%
from datetime import datetime

# Obtener fecha mínima y máxima del dataset
df_merged["date"] = pd.to_datetime(df_merged[["year", "month", "day"]])

start_date = df_merged["date"].min().strftime("%Y-%m-%d")
end_date = df_merged["date"].max().strftime("%Y-%m-%d")

# %%
import pandas as pd
import os
import requests
from time import sleep

# === Crear carpeta para los CSV meteorológicos ===
os.makedirs("meteo_csv", exist_ok=True)


# === Descargar CSV por estación ===
for _, row in stations.iterrows():
    sid = row["station_id"]
    lat = row["lat"]
    lon = row["lon"]

    output_path = f"meteo_csv/station_{sid}.csv"
    if os.path.exists(output_path):
        print(f"[✓] CSV ya existe para estación {sid}")
        continue

    print(f"[↓] Descargando estación {sid}...")
    url = (
        f"https://archive-api.open-meteo.com/v1/archive?"
        f"latitude={lat}&longitude={lon}"
        f"&start_date={start_date}&end_date={end_date}"
        f"&hourly=temperature_2m,relative_humidity_2m,precipitation"
        f"&timezone=Europe%2FMadrid&format=csv"
    )

    try:
        r = requests.get(url)
        r.raise_for_status()
        with open(output_path, "wb") as f:
            f.write(r.content)
        sleep(1)  # para evitar rate limit
    except Exception as e:
        print(f"Error al descargar estación {sid}: {e}")
# Out:
# [↓] Descargando estación 1.0...
# [↓] Descargando estación 10.0...
# [↓] Descargando estación 100.0...
# [↓] Descargando estación 101.0...
# [↓] Descargando estación 102.0...
# [↓] Descargando estación 103.0...
# [↓] Descargando estación 104.0...
# [↓] Descargando estación 105.0...
# [↓] Descargando estación 106.0...
# [↓] Descargando estación 107.0...
# [↓] Descargando estación 108.0...
# [↓] Descargando estación 109.0...
# [↓] Descargando estación 11.0...
# [↓] Descargando estación 110.0...
# [↓] Descargando estación 111.0...
# [↓] Descargando estación 112.0...
# [↓] Descargando estación 113.0...
# [↓] Descargando estación 114.0...
# [↓] Descargando estación 115.0...
# [↓] Descargando estación 116.0...
# [↓] Descargando estación 117.0...
# [↓] Descargando estación 118.0...
# [↓] Descargando estación 119.0...
# [↓] Descargando estación 12.0...
# [↓] Descargando estación 120.0...
# [↓] Descargando estación 121.0...
# [↓] Descargando estación 122.0...
# [↓] Descargando estación 123.0...
# [↓] Descargando estación 124.0...
# [↓] Descargando estación 125.0...
# [↓] Descargando estación 126.0...
# [↓] Descargando estación 127.0...
# [↓] Descargando estación 128.0...
# [↓] Descargando estación 129.0...
# [↓] Descargando estación 13.0...
# [↓] Descargando estación 130.0...
# [↓] Descargando estación 131.0...
# [↓] Descargando estación 132.0...
# [↓] Descargando estación 133.0...
# [↓] Descargando estación 134.0...
# [↓] Descargando estación 135.0...
# [↓] Descargando estación 136.0...
# [↓] Descargando estación 137.0...
# [↓] Descargando estación 138.0...
# [↓] Descargando estación 139.0...
# [↓] Descargando estación 14.0...
# [↓] Descargando estación 140.0...
# [↓] Descargando estación 141.0...
# [↓] Descargando estación 142.0...
# [↓] Descargando estación 143.0...
# [↓] Descargando estación 144.0...
# [↓] Descargando estación 145.0...
# [↓] Descargando estación 146.0...
# [↓] Descargando estación 147.0...
# [↓] Descargando estación 148.0...
# [↓] Descargando estación 149.0...
# [↓] Descargando estación 15.0...
# [↓] Descargando estación 150.0...
# [↓] Descargando estación 151.0...
# [↓] Descargando estación 152.0...
# [↓] Descargando estación 153.0...
# [↓] Descargando estación 154.0...
# [↓] Descargando estación 155.0...
# [↓] Descargando estación 156.0...
# [↓] Descargando estación 157.0...
# [↓] Descargando estación 158.0...
# [↓] Descargando estación 159.0...
# [↓] Descargando estación 160.0...
# [↓] Descargando estación 161.0...
# [↓] Descargando estación 162.0...
# [↓] Descargando estación 164.0...
# [↓] Descargando estación 165.0...
# [↓] Descargando estación 166.0...
# [↓] Descargando estación 167.0...
# [↓] Descargando estación 168.0...
# [↓] Descargando estación 17.0...
# [↓] Descargando estación 170.0...
# [↓] Descargando estación 171.0...
# [↓] Descargando estación 173.0...
# [↓] Descargando estación 174.0...
# [↓] Descargando estación 175.0...
# [↓] Descargando estación 176.0...
# [↓] Descargando estación 177.0...
# [↓] Descargando estación 178.0...
# [↓] Descargando estación 179.0...
# [↓] Descargando estación 18.0...
# [↓] Descargando estación 180.0...
# [↓] Descargando estación 182.0...
# [↓] Descargando estación 183.0...
# [↓] Descargando estación 184.0...
# [↓] Descargando estación 185.0...
# [↓] Descargando estación 186.0...
# [↓] Descargando estación 187.0...
# [↓] Descargando estación 188.0...
# [↓] Descargando estación 189.0...
# [↓] Descargando estación 19.0...
# [↓] Descargando estación 190.0...
# [↓] Descargando estación 191.0...
# [↓] Descargando estación 192.0...
# [↓] Descargando estación 193.0...
# [↓] Descargando estación 194.0...
# [↓] Descargando estación 195.0...
# [↓] Descargando estación 196.0...
# [↓] Descargando estación 197.0...
# [↓] Descargando estación 198.0...
# [↓] Descargando estación 199.0...
# [↓] Descargando estación 2.0...
# [↓] Descargando estación 20.0...
# [↓] Descargando estación 200.0...
# [↓] Descargando estación 201.0...
# [↓] Descargando estación 202.0...
# [↓] Descargando estación 203.0...
# [↓] Descargando estación 204.0...
# [↓] Descargando estación 205.0...
# [↓] Descargando estación 206.0...
# [↓] Descargando estación 207.0...
# [↓] Descargando estación 208.0...
# [↓] Descargando estación 209.0...
# [↓] Descargando estación 21.0...
# [↓] Descargando estación 210.0...
# [↓] Descargando estación 211.0...
# [↓] Descargando estación 212.0...
# [↓] Descargando estación 213.0...
# [↓] Descargando estación 214.0...
# [↓] Descargando estación 215.0...
# [↓] Descargando estación 216.0...
# [↓] Descargando estación 217.0...
# [↓] Descargando estación 218.0...
# [↓] Descargando estación 219.0...
# [↓] Descargando estación 22.0...
# [↓] Descargando estación 220.0...
# [↓] Descargando estación 221.0...
# [↓] Descargando estación 222.0...
# [↓] Descargando estación 223.0...
# [↓] Descargando estación 224.0...
# [↓] Descargando estación 225.0...
# [↓] Descargando estación 226.0...
# [↓] Descargando estación 227.0...
# [↓] Descargando estación 228.0...
# [↓] Descargando estación 229.0...
# [↓] Descargando estación 23.0...
# [↓] Descargando estación 230.0...
# [↓] Descargando estación 232.0...
# [↓] Descargando estación 233.0...
# [↓] Descargando estación 234.0...
# [↓] Descargando estación 235.0...
# [↓] Descargando estación 236.0...
# [↓] Descargando estación 237.0...
# [↓] Descargando estación 238.0...
# [↓] Descargando estación 239.0...
# [↓] Descargando estación 24.0...
# [↓] Descargando estación 240.0...
# [↓] Descargando estación 241.0...
# [↓] Descargando estación 242.0...
# [↓] Descargando estación 243.0...
# [↓] Descargando estación 244.0...
# [↓] Descargando estación 245.0...
# [↓] Descargando estación 246.0...
# [↓] Descargando estación 247.0...
# [↓] Descargando estación 248.0...
# [↓] Descargando estación 249.0...
# [↓] Descargando estación 25.0...
# [↓] Descargando estación 250.0...
# [↓] Descargando estación 251.0...
# [↓] Descargando estación 252.0...
# [↓] Descargando estación 253.0...
# [↓] Descargando estación 254.0...
# [↓] Descargando estación 255.0...
# [↓] Descargando estación 256.0...
# [↓] Descargando estación 257.0...
# [↓] Descargando estación 258.0...
# [↓] Descargando estación 259.0...
# [↓] Descargando estación 26.0...
# [↓] Descargando estación 260.0...
# [↓] Descargando estación 261.0...
# [↓] Descargando estación 262.0...
# [↓] Descargando estación 263.0...
# [↓] Descargando estación 264.0...
# [↓] Descargando estación 265.0...
# [↓] Descargando estación 266.0...
# [↓] Descargando estación 267.0...
# [↓] Descargando estación 268.0...
# [↓] Descargando estación 269.0...
# [↓] Descargando estación 27.0...
# [↓] Descargando estación 270.0...
# [↓] Descargando estación 271.0...
# [↓] Descargando estación 272.0...
# [↓] Descargando estación 273.0...
# [↓] Descargando estación 274.0...
# [↓] Descargando estación 275.0...
# [↓] Descargando estación 276.0...
# [↓] Descargando estación 277.0...
# [↓] Descargando estación 278.0...
# [↓] Descargando estación 279.0...
# [↓] Descargando estación 28.0...
# [↓] Descargando estación 280.0...
# [↓] Descargando estación 281.0...
# [↓] Descargando estación 282.0...
# [↓] Descargando estación 283.0...
# [↓] Descargando estación 284.0...
# [↓] Descargando estación 285.0...
# [↓] Descargando estación 286.0...
# [↓] Descargando estación 287.0...
# [↓] Descargando estación 288.0...
# [↓] Descargando estación 289.0...
# [↓] Descargando estación 29.0...
# [↓] Descargando estación 290.0...
# [↓] Descargando estación 291.0...
# [↓] Descargando estación 292.0...
# [↓] Descargando estación 293.0...
# [↓] Descargando estación 294.0...
# [↓] Descargando estación 295.0...
# [↓] Descargando estación 296.0...
# [↓] Descargando estación 297.0...
# [↓] Descargando estación 298.0...
# [↓] Descargando estación 299.0...
# [↓] Descargando estación 3.0...
# [↓] Descargando estación 30.0...
# [↓] Descargando estación 300.0...
# [↓] Descargando estación 301.0...
# [↓] Descargando estación 302.0...
# [↓] Descargando estación 303.0...
# [↓] Descargando estación 304.0...
# [↓] Descargando estación 305.0...
# [↓] Descargando estación 306.0...
# [↓] Descargando estación 307.0...
# [↓] Descargando estación 308.0...
# [↓] Descargando estación 309.0...
# [↓] Descargando estación 31.0...
# [↓] Descargando estación 310.0...
# [↓] Descargando estación 311.0...
# [↓] Descargando estación 312.0...
# [↓] Descargando estación 313.0...
# [↓] Descargando estación 314.0...
# [↓] Descargando estación 315.0...
# [↓] Descargando estación 316.0...
# [↓] Descargando estación 317.0...
# [↓] Descargando estación 318.0...
# [↓] Descargando estación 319.0...
# [↓] Descargando estación 32.0...
# [↓] Descargando estación 320.0...
# [↓] Descargando estación 321.0...
# [↓] Descargando estación 322.0...
# [↓] Descargando estación 323.0...
# [↓] Descargando estación 324.0...
# [↓] Descargando estación 325.0...
# [↓] Descargando estación 326.0...
# [↓] Descargando estación 327.0...
# [↓] Descargando estación 328.0...
# [↓] Descargando estación 329.0...
# [↓] Descargando estación 330.0...
# [↓] Descargando estación 331.0...
# [↓] Descargando estación 332.0...
# [↓] Descargando estación 333.0...
# [↓] Descargando estación 334.0...
# [↓] Descargando estación 335.0...
# [↓] Descargando estación 336.0...
# [↓] Descargando estación 337.0...
# [↓] Descargando estación 338.0...
# [↓] Descargando estación 339.0...
# [↓] Descargando estación 34.0...
# [↓] Descargando estación 340.0...
# [↓] Descargando estación 341.0...
# [↓] Descargando estación 342.0...
# [↓] Descargando estación 343.0...
# [↓] Descargando estación 344.0...
# [↓] Descargando estación 345.0...
# [↓] Descargando estación 346.0...
# [↓] Descargando estación 347.0...
# [↓] Descargando estación 348.0...
# [↓] Descargando estación 349.0...
# [↓] Descargando estación 35.0...
# [↓] Descargando estación 350.0...
# [↓] Descargando estación 351.0...
# [↓] Descargando estación 352.0...
# [↓] Descargando estación 353.0...
# [↓] Descargando estación 354.0...
# [↓] Descargando estación 355.0...
# [↓] Descargando estación 356.0...
# [↓] Descargando estación 357.0...
# [↓] Descargando estación 358.0...
# [↓] Descargando estación 359.0...
# [↓] Descargando estación 36.0...
# [↓] Descargando estación 360.0...
# [↓] Descargando estación 361.0...
# [↓] Descargando estación 362.0...
# [↓] Descargando estación 363.0...
# [↓] Descargando estación 364.0...
# [↓] Descargando estación 365.0...
# [↓] Descargando estación 366.0...
# [↓] Descargando estación 367.0...
# [↓] Descargando estación 368.0...
# [↓] Descargando estación 369.0...
# [↓] Descargando estación 37.0...
# [↓] Descargando estación 370.0...
# [↓] Descargando estación 371.0...
# [↓] Descargando estación 372.0...
# [↓] Descargando estación 373.0...
# [↓] Descargando estación 374.0...
# [↓] Descargando estación 375.0...
# [↓] Descargando estación 376.0...
# [↓] Descargando estación 377.0...
# [↓] Descargando estación 378.0...
# [↓] Descargando estación 379.0...
# [↓] Descargando estación 380.0...
# [↓] Descargando estación 381.0...
# [↓] Descargando estación 382.0...
# [↓] Descargando estación 383.0...
# [↓] Descargando estación 384.0...
# [↓] Descargando estación 385.0...
# [↓] Descargando estación 386.0...
# [↓] Descargando estación 387.0...
# [↓] Descargando estación 388.0...
# [↓] Descargando estación 389.0...
# [↓] Descargando estación 39.0...
# [↓] Descargando estación 390.0...
# [↓] Descargando estación 391.0...
# [↓] Descargando estación 392.0...
# [↓] Descargando estación 393.0...
# [↓] Descargando estación 394.0...
# [↓] Descargando estación 395.0...
# Error al descargar estación 395.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3860607&longitude=2.1702467&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 396.0...
# Error al descargar estación 396.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3890253&longitude=2.1968267&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 397.0...
# Error al descargar estación 397.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3889129&longitude=2.1993105&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 398.0...
# Error al descargar estación 398.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.380955&longitude=2.1934636&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 399.0...
# Error al descargar estación 399.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3734706&longitude=2.1332694&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 4.0...
# Error al descargar estación 4.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3933173&longitude=2.1812483&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 40.0...
# Error al descargar estación 40.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.382335&longitude=2.187093&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 400.0...
# Error al descargar estación 400.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3694508&longitude=2.1879597&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 401.0...
# Error al descargar estación 401.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.382418&longitude=2.183723&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 402.0...
# Error al descargar estación 402.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.380628&longitude=2.1821917&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 403.0...
# Error al descargar estación 403.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3796421&longitude=2.1368202&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 404.0...
# Error al descargar estación 404.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3653426&longitude=2.1331357&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 405.0...
# Error al descargar estación 405.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3854003&longitude=2.1521802&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 406.0...
# Error al descargar estación 406.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3863747&longitude=2.1646697&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 408.0...
# Error al descargar estación 408.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3889972&longitude=2.1923283&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 409.0...
# Error al descargar estación 409.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.392384&longitude=2.1925059&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 41.0...
# Error al descargar estación 41.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.379326&longitude=2.189906&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 410.0...
# Error al descargar estación 410.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.376433&longitude=2.17871&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 411.0...
# Error al descargar estación 411.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.411381&longitude=2.2122054&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 412.0...
# Error al descargar estación 412.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3893094&longitude=2.1727457&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 413.0...
# Error al descargar estación 413.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.393489&longitude=2.1707419&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 414.0...
# Error al descargar estación 414.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3937234&longitude=2.1764275&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 415.0...
# Error al descargar estación 415.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3793558&longitude=2.1689592&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 416.0...
# Error al descargar estación 416.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3781065&longitude=2.1696744&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 417.0...
# Error al descargar estación 417.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4164824&longitude=2.1801094&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 418.0...
# Error al descargar estación 418.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.391062&longitude=2.1801142&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 419.0...
# Error al descargar estación 419.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.391313&longitude=2.1808391&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 42.0...
# Error al descargar estación 42.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.404511&longitude=2.189881&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 420.0...
# Error al descargar estación 420.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3743329&longitude=2.1479385&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 421.0...
# Error al descargar estación 421.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.378118&longitude=2.1378667&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 422.0...
# Error al descargar estación 422.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3881175&longitude=2.1154135&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 423.0...
# Error al descargar estación 423.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4202459&longitude=2.1894852&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 424.0...
# Error al descargar estación 424.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3795862&longitude=2.1925198&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 425.0...
# Error al descargar estación 425.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3765618&longitude=2.1748621&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 426.0...
# Error al descargar estación 426.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.39828&longitude=2.1830315&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 427.0...
# Error al descargar estación 427.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3754047&longitude=2.1680021&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 428.0...
# Error al descargar estación 428.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3983902&longitude=2.1960799&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 429.0...
# Error al descargar estación 429.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3881262&longitude=2.1091535&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 43.0...
# Error al descargar estación 43.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4063864&longitude=2.1874404&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 430.0...
# Error al descargar estación 430.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.385641&longitude=2.113096&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 431.0...
# Error al descargar estación 431.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.383467&longitude=2.122175&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 432.0...
# Error al descargar estación 432.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3847061&longitude=2.1170751&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 433.0...
# Error al descargar estación 433.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3862258&longitude=2.1168609&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 434.0...
# Error al descargar estación 434.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3767538&longitude=2.1269152&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 435.0...
# Error al descargar estación 435.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.383585&longitude=2.112186&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 436.0...
# Error al descargar estación 436.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3545425&longitude=2.1433038&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 437.0...
# Error al descargar estación 437.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3513237&longitude=2.1450958&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 438.0...
# Error al descargar estación 438.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3981669&longitude=2.1754896&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 439.0...
# Error al descargar estación 439.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3685394&longitude=2.1328403&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 440.0...
# Error al descargar estación 440.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.417694&longitude=2.1976864&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 441.0...
# Error al descargar estación 441.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3754426&longitude=2.1398409&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 442.0...
# Error al descargar estación 442.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3649272&longitude=2.138599&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 443.0...
# Error al descargar estación 443.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3887127&longitude=2.1542277&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 444.0...
# Error al descargar estación 444.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3717304&longitude=2.1554047&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 445.0...
# Error al descargar estación 445.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3755016&longitude=2.154004&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 446.0...
# Error al descargar estación 446.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3779974&longitude=2.1884228&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 447.0...
# Error al descargar estación 447.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3943033&longitude=2.1860256&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 448.0...
# Error al descargar estación 448.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3972809&longitude=2.1997869&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 449.0...
# Error al descargar estación 449.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4058109&longitude=2.1949461&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 45.0...
# Error al descargar estación 45.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.391466&longitude=2.189371&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 450.0...
# Error al descargar estación 450.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.410712&longitude=2.2061691&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 451.0...
# Error al descargar estación 451.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4140598&longitude=2.2150487&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 452.0...
# Error al descargar estación 452.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4194972&longitude=2.20934&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 454.0...
# Error al descargar estación 454.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4072349&longitude=2.1684799&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 455.0...
# Error al descargar estación 455.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4105848&longitude=2.1826833&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 456.0...
# Error al descargar estación 456.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4143392&longitude=2.1874539&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 457.0...
# Error al descargar estación 457.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4383117&longitude=2.2039823&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 458.0...
# Error al descargar estación 458.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4457962&longitude=2.2010422&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 459.0...
# Error al descargar estación 459.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4479402&longitude=2.1976757&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 46.0...
# Error al descargar estación 46.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.38860659692564&longitude=2.1921945084594707&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 460.0...
# Error al descargar estación 460.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4513863&longitude=2.1894717&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 461.0...
# Error al descargar estación 461.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.442489&longitude=2.185727&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 462.0...
# Error al descargar estación 462.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.446923&longitude=2.184857&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 463.0...
# Error al descargar estación 463.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4490679&longitude=2.1833801&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 464.0...
# Error al descargar estación 464.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.439692&longitude=2.182335&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 465.0...
# Error al descargar estación 465.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3954094&longitude=2.1599427&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 466.0...
# Error al descargar estación 466.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.443387&longitude=2.1813051&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 467.0...
# Error al descargar estación 467.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4450463&longitude=2.176726&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 468.0...
# Error al descargar estación 468.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4480464&longitude=2.1775154&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 469.0...
# Error al descargar estación 469.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4417001&longitude=2.1781553&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 47.0...
# Error al descargar estación 47.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3902194&longitude=2.1904003&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 470.0...
# Error al descargar estación 470.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4432762&longitude=2.1746238&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 471.0...
# Error al descargar estación 471.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4389014&longitude=2.1715576&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 472.0...
# Error al descargar estación 472.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4427374&longitude=2.170393&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 473.0...
# Error al descargar estación 473.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4388644&longitude=2.1657506&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 474.0...
# Error al descargar estación 474.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4418604&longitude=2.1664224&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 475.0...
# Error al descargar estación 475.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4216738&longitude=2.1799878&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 476.0...
# Error al descargar estación 476.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.422037&longitude=2.174401&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 477.0...
# Error al descargar estación 477.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4260751&longitude=2.1722534&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 478.0...
# Error al descargar estación 478.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4276076&longitude=2.1697582&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 479.0...
# Error al descargar estación 479.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.430623&longitude=2.1671068&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 48.0...
# Error al descargar estación 48.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3960652&longitude=2.1871959&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 480.0...
# Error al descargar estación 480.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4333259&longitude=2.1629258&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 481.0...
# Error al descargar estación 481.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4357978&longitude=2.163872&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 482.0...
# Error al descargar estación 482.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4372022&longitude=2.1620235&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 483.0...
# Error al descargar estación 483.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.429561735076526&longitude=2.158968456344588&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 484.0...
# Error al descargar estación 484.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4345997&longitude=2.1585268&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 485.0...
# Error al descargar estación 485.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4374904&longitude=2.1565742&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 486.0...
# Error al descargar estación 486.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4306102&longitude=2.1564551&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 487.0...
# Error al descargar estación 487.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4267638&longitude=2.1521909&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 488.0...
# Error al descargar estación 488.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4347859&longitude=2.147904&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 489.0...
# Error al descargar estación 489.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4312335&longitude=2.1499103&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 49.0...
# Error al descargar estación 49.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3910756&longitude=2.1965766&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 490.0...
# Error al descargar estación 490.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4280668&longitude=2.1443777&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 491.0...
# Error al descargar estación 491.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4306689&longitude=2.1456449&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 492.0...
# Error al descargar estación 492.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3943454&longitude=2.1751709&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 493.0...
# Error al descargar estación 493.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.419965&longitude=2.1401823&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 494.0...
# Error al descargar estación 494.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3896967&longitude=2.1652199&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 495.0...
# Error al descargar estación 495.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.377846&longitude=2.150523&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 496.0...
# Error al descargar estación 496.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4048623&longitude=2.174799&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 497.0...
# Error al descargar estación 497.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.4095489&longitude=2.1360313&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# ...
# [↓] Descargando estación 53.0...
# Error al descargar estación 53.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.385086&longitude=2.174016&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 54.0...
# Error al descargar estación 54.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3775319&longitude=2.1707321&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 56.0...
# Error al descargar estación 56.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3770715&longitude=2.1758261&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 57.0...
# Error al descargar estación 57.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.376326&longitude=2.176971&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 58.0...
# Error al descargar estación 58.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.38268&longitude=2.16712&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 6.0...
# Error al descargar estación 6.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3914292&longitude=2.1805685&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 60.0...
# Error al descargar estación 60.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3902625&longitude=2.164035&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 61.0...
# Error al descargar estación 61.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.39352&longitude=2.166797&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 62.0...
# Error al descargar estación 62.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.387235&longitude=2.168819&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 63.0...
# Error al descargar estación 63.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.386543&longitude=2.169427&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 64.0...
# Error al descargar estación 64.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.387493&longitude=2.1690686&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 65.0...
# Error al descargar estación 65.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.387696&longitude=2.1696543&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 66.0...
# Error al descargar estación 66.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3893222&longitude=2.1678388&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 67.0...
# Error al descargar estación 67.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3852864&longitude=2.1454802&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 68.0...
# Error al descargar estación 68.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3953894&longitude=2.1572953&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 69.0...
# Error al descargar estación 69.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.388507&longitude=2.195073&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 7.0...
# Error al descargar estación 7.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.388885&longitude=2.18329&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 70.0...
# Error al descargar estación 70.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.380393&longitude=2.1606506&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 71.0...
# Error al descargar estación 71.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3819459&longitude=2.1629146&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 72.0...
# Error al descargar estación 72.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3927771&longitude=2.1586273&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 73.0...
# Error al descargar estación 73.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.392135&longitude=2.1563542&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 74.0...
# Error al descargar estación 74.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3900085&longitude=2.1432105&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 75.0...
# Error al descargar estación 75.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.385004&longitude=2.1429115&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 76.0...
# Error al descargar estación 76.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3917666&longitude=2.1532163&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 77.0...
# Error al descargar estación 77.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3855644&longitude=2.1773214&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 78.0...
# Error al descargar estación 78.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3856474&longitude=2.1634306&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 79.0...
# Error al descargar estación 79.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.385503&longitude=2.1634768&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 8.0...
# Error al descargar estación 8.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.389135&longitude=2.183489&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 80.0...
# Error al descargar estación 80.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.389668&longitude=2.1599078&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 81.0...
# Error al descargar estación 81.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3790718&longitude=2.1490553&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 82.0...
# Error al descargar estación 82.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.38031805998654&longitude=2.154437124811396&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 83.0...
# Error al descargar estación 83.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3821658&longitude=2.1520645&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 84.0...
# Error al descargar estación 84.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3830299&longitude=2.1571646&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 85.0...
# Error al descargar estación 85.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3751852&longitude=2.1592394&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 86.0...
# Error al descargar estación 86.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3755747&longitude=2.1629349&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 87.0...
# Error al descargar estación 87.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.38322238887374&longitude=2.147993191629656&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 88.0...
# Error al descargar estación 88.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3936144&longitude=2.1507739&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 89.0...
# Error al descargar estación 89.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3871904&longitude=2.149131&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 9.0...
# Error al descargar estación 9.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.384546&longitude=2.184922&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 90.0...
# Error al descargar estación 90.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.388296&longitude=2.150878&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 91.0...
# Error al descargar estación 91.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3812504&longitude=2.1594741&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 92.0...
# Error al descargar estación 92.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3938861&longitude=2.1601641&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 94.0...
# Error al descargar estación 94.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3757914&longitude=2.1499102&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 95.0...
# Error al descargar estación 95.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3763948&longitude=2.1473272&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 96.0...
# Error al descargar estación 96.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3741093&longitude=2.1481993&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 97.0...
# Error al descargar estación 97.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3779613&longitude=2.1450491&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 98.0...
# Error al descargar estación 98.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3806074&longitude=2.1408633&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv
# [↓] Descargando estación 99.0...
# Error al descargar estación 99.0: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=41.3808222&longitude=2.141539&start_date=2021-01-01&end_date=2022-12-31&hourly=temperature_2m,relative_humidity_2m,precipitation&timezone=Europe%2FMadrid&format=csv

# %%
# Eliminar la columna "Unnamed: 0" de X_train
#X_train = X_train.drop(columns=['Unnamed: 0','year'])
#X_test = X_test.drop(columns=['year'])


# Establecer la columna "index" como índice en X_test

# %%
from datetime import datetime

# Asegurar tipo int para las columnas de fecha
X_test["year"] = X_test["year"].astype(int)
X_test["month"] = X_test["month"].astype(int)
X_test["day"] = X_test["day"].astype(int)

# Crear columna de fecha
X_test["date"] = pd.to_datetime(X_test[["year", "month", "day"]])

# Obtener fechas mínima y máxima
start_date_test = X_test["date"].min().strftime("%Y-%m-%d")
end_date_test = X_test["date"].max().strftime("%Y-%m-%d")

# %%
import pandas as pd
import os
import requests
from time import sleep

# === Crear carpeta para los CSV meteorológicos ===
os.makedirs("meteo_test_csv", exist_ok=True)


# === Descargar CSV por estación ===
for _, row in stations.iterrows():
    sid = row["station_id"]
    lat = row["lat"]
    lon = row["lon"]

    output_path = f"meteo_test_csv/station_{sid}.csv"
    if os.path.exists(output_path):
        print(f"[✓] CSV ya existe para estación {sid}")
        continue

    print(f"[↓] Descargando estación {sid}...")
    url = (
        f"https://archive-api.open-meteo.com/v1/archive?"
        f"latitude={lat}&longitude={lon}"
        f"&start_date={start_date_test}&end_date={end_date_test}"
        f"&hourly=temperature_2m,relative_humidity_2m,precipitation"
        f"&timezone=Europe%2FMadrid&format=csv"
    )

    try:
        r = requests.get(url)
        r.raise_for_status()
        with open(output_path, "wb") as f:
            f.write(r.content)
        sleep(1)  # para evitar rate limit
    except Exception as e:
        print(f"Error al descargar estación {sid}: {e}")

# %%
import zipfile
import os

def zip_folder(folder_name, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_name):
            for file in files:
                filepath = os.path.join(root, file)
                arcname = os.path.relpath(filepath, start=os.path.dirname(folder_name))
                zipf.write(filepath, arcname)

# Comprimir cada carpeta por separado
zip_folder("meteo_csv", "meteo_csv.zip")
zip_folder("meteo_test_csv", "meteo_test_csv.zip")

# %% [markdown]
# ## Add Columns

# %%
import zipfile

with zipfile.ZipFile("meteo_test_csv.zip", 'r') as zip_ref:
    zip_ref.extractall()

with zipfile.ZipFile("meteo_csv.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
import shutil

shutil.rmtree("meteo_test_csv", ignore_errors=True)

# %%
import pandas as pd
from io import StringIO
import os
import re

def transform_csv_to_df(path):
    try:
        with open(path, "r", encoding="utf-8") as f:
            lines = f.readlines()

        # Buscar línea que contenga tanto 'time' como 'temperature'
        header_idx = next(
            i for i, line in enumerate(lines)
            if "time" in line.lower() and "temperature" in line.lower()
        )

        # Extraer cabecera
        header = lines[header_idx].strip().split(",")

        # Datos desde la línea siguiente
        data_lines = lines[header_idx + 1:]

        # Si la primera línea de datos repite la cabecera, saltarla
        first_data_line = data_lines[0].strip().split(",")
        if all(a.strip() == b.strip() for a, b in zip(first_data_line, header)):
            data_lines = data_lines[1:]

        # Leer como CSV
        data_str = "".join(data_lines)
        df = pd.read_csv(StringIO(data_str), header=None)
        df.columns = header[:len(df.columns)]

        # Extraer station_id del nombre del archivo
        filename = os.path.basename(path)
        match = re.search(r"station_(\d+(?:\.\d+)?)", filename)
        station_id = int(float(match.group(1))) if match else None
        df["station_id"] = station_id

        #print("Columnas detectadas:")
        #print(df.columns.tolist())
        #print("\nPrimeras filas:")
        #print(df.head())

        return df

    except Exception as e:
        print(f"[!] Error al leer {path}: {e}")

# %%
df_weather_train = transform_csv_to_df("meteo_csv/station_105.0.csv")
df_weather_train
# Out:
#                    time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0      2021-01-01T00:00                  5.7                        82
# 1      2021-01-01T01:00                  6.5                        79
# 2      2021-01-01T02:00                  5.0                        83
# 3      2021-01-01T03:00                  4.7                        84
# 4      2021-01-01T04:00                  4.6                        86
# ...                 ...                  ...                       ...
# 17515  2022-12-31T19:00                 13.7                        74
# 17516  2022-12-31T20:00                 12.5                        78
# 17517  2022-12-31T21:00                 11.5                        85
# 17518  2022-12-31T22:00                 10.5                        87
# 17519  2022-12-31T23:00                 10.2                        87
#
#        precipitation (mm)  station_id
# 0                     0.0         105
# 1                     0.0         105
# 2                     0.0         105
# 3                     0.0         105
# 4                     0.0         105
# ...                   ...         ...
# 17515                 0.0         105
# 17516                 0.0         105
# 17517                 0.0         105
# 17518                 0.0         105
# 17519                 0.0         105
#
# [17520 rows x 5 columns]

# %%
X_train
# Out:
#           station_id  year  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 8163               1  2021      1    1     0  0.043478  0.045290  0.050725
# 8164               1  2021      1    1     1  0.045290  0.050725  0.063406
# 8165               1  2021      1    1     2  0.050725  0.063406  0.119565
# 8166               1  2021      1    1     3  0.063406  0.119565  0.108696
# 8167               1  2021      1    1     4  0.119565  0.108696  0.108696
# ...              ...   ...    ...  ...   ...       ...       ...       ...
# 12684382          99  2022     12   31    19  0.468254  0.657738  0.615079
# 12684383          99  2022     12   31    20  0.657738  0.615079  0.686508
# 12684384          99  2022     12   31    21  0.615079  0.686508  0.603175
# 12684385          99  2022     12   31    22  0.686508  0.603175  0.571429
# 12684386          99  2022     12   31    23  0.603175  0.571429  0.567460
#
#              ctx-1     ctx-0
# 8163      0.063406  0.119565
# 8164      0.119565  0.108696
# 8165      0.108696  0.108696
# 8166      0.108696  0.108696
# 8167      0.108696  0.108696
# ...            ...       ...
# 12684382  0.686508  0.603175
# 12684383  0.603175  0.571429
# 12684384  0.571429  0.567460
# 12684385  0.567460  0.531746
# 12684386  0.531746  0.460317
#
# [8835694 rows x 10 columns]

# %%
X_test
# Out:
#          index  station_id  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0            0           1      6    1     3  0.490942  0.378623  0.324275
# 1            1           1      6    1     8  0.271739  0.311594  0.346014
# 2            2           1      6    1    13  0.538043  0.650362  0.697464
# 3            3           1      6    1    18  0.789855  0.800725  0.791667
# 4            4           1      6    1    23  0.860507  0.871377  0.817029
# ...        ...         ...    ...  ...   ...       ...       ...       ...
# 401506  401506         496     12   31     2  0.865741  0.643519  0.597222
# 401507  401507         496     12   31     7  1.000000  0.388889  0.375000
# 401508  401508         496     12   31    12  0.310185  0.337963  0.402778
# 401509  401509         496     12   31    17  0.462963  0.564815  0.629630
# 401510  401510         496     12   31    22  0.467593  0.361111  0.546296
#
#            ctx-1  year
# 0       0.311594  2024
# 1       0.394928  2024
# 2       0.721014  2024
# 3       0.807971  2024
# 4       0.793478  2024
# ...          ...   ...
# 401506  0.921296  2024
# 401507  0.407407  2024
# 401508  0.495370  2024
# 401509  0.583333  2024
# 401510  0.550926  2024
#
# [401511 rows x 10 columns]

# %%
import pandas as pd
import os
from glob import glob

def merge_meteo_with_X_train(meteo_folder, X_train):
    # 1. Leer todos los CSV de meteo_csv/
    all_csv_paths = glob(os.path.join(meteo_folder, "*.csv"))
    meteo_dfs = [transform_csv_to_df(p) for p in all_csv_paths]

    # 2. Concatenar todos los DataFrames de meteorología
    meteo_df = pd.concat(meteo_dfs, ignore_index=True)

    # 3. Convertir columna "time" en datetime
    meteo_df["time"] = pd.to_datetime(meteo_df["time"])

    # 4. Crear columna datetime en X_train
    X_train = X_train.copy()
    X_train["time"] = pd.to_datetime(X_train[["year", "month", "day", "hour"]])

    # 5. Merge por station_id y time
    merged_df = pd.merge(
        X_train,
        meteo_df[["station_id", "time", "temperature_2m (°C)", "precipitation (mm)"]],
        on=["station_id", "time"],
        how="left"
    )

    # 6. Rellenar NaNs con la media global de cada columna meteorológica
    for col in ["temperature_2m (°C)", "precipitation (mm)"]:
        if col in merged_df.columns:
            merged_df[col].fillna(merged_df[col].mean(), inplace=True)

    # 7. Eliminar columnas no necesarias
    merged_df.drop(columns=["time"], inplace=True)

    return merged_df

# %%
X_train_enriquecido = merge_meteo_with_X_train("meteo_csv", X_train)
X_train_enriquecido
# Out:
#           station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                  1  2021.0    1.0   1.0   0.0  0.043478  0.045290  0.050725
# 1                  1  2021.0    1.0   1.0   1.0  0.045290  0.050725  0.063406
# 2                  1  2021.0    1.0   1.0   2.0  0.050725  0.063406  0.119565
# 3                  1  2021.0    1.0   1.0   3.0  0.063406  0.119565  0.108696
# 4                  1  2021.0    1.0   1.0   4.0  0.119565  0.108696  0.108696
# ...              ...     ...    ...   ...   ...       ...       ...       ...
# 12949695          99  2023.0   12.0  31.0  19.0  0.320175  0.144737  0.208333
# 12949696          99  2023.0   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 12949697          99  2023.0   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 12949698          99  2023.0   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 12949699          99  2023.0   12.0  31.0  23.0  0.041667  0.016667  0.045833
#
#              ctx-1     ctx-0  temperature_2m (°C)  precipitation (mm)
# 0         0.063406  0.119565             5.700000            0.000000
# 1         0.119565  0.108696             6.500000            0.000000
# 2         0.108696  0.108696             5.000000            0.000000
# 3         0.108696  0.108696             4.700000            0.000000
# 4         0.108696  0.108696             4.600000            0.000000
# ...            ...       ...                  ...                 ...
# 12949695  0.150000  0.041667            16.683865            0.064191
# 12949696  0.041667  0.016667            16.683865            0.064191
# 12949697  0.016667  0.045833            16.683865            0.064191
# 12949698  0.045833  0.000000            16.683865            0.064191
# 12949699  0.000000  0.000000            16.683865            0.064191
#
# [12949700 rows x 12 columns]

# %%
X_test_enriquecido = merge_meteo_with_X_train("meteo_test_csv", X_test)
X_test_enriquecido.set_index('index', inplace=True)
X_test_enriquecido
# Out:
#         station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# index
# 0                1      6    1     3  0.490942  0.378623  0.324275  0.311594
# 1                1      6    1     8  0.271739  0.311594  0.346014  0.394928
# 2                1      6    1    13  0.538043  0.650362  0.697464  0.721014
# 3                1      6    1    18  0.789855  0.800725  0.791667  0.807971
# 4                1      6    1    23  0.860507  0.871377  0.817029  0.793478
# ...            ...    ...  ...   ...       ...       ...       ...       ...
# 401506         496     12   31     2  0.865741  0.643519  0.597222  0.921296
# 401507         496     12   31     7  1.000000  0.388889  0.375000  0.407407
# 401508         496     12   31    12  0.310185  0.337963  0.402778  0.495370
# 401509         496     12   31    17  0.462963  0.564815  0.629630  0.583333
# 401510         496     12   31    22  0.467593  0.361111  0.546296  0.550926
#
#         year  temperature_2m (°C)  precipitation (mm)
# index
# 0       2024            16.200000             1.40000
# 1       2024            18.100000             0.00000
# 2       2024            22.200000             0.00000
# 3       2024            20.300000             0.80000
# 4       2024            16.600000             0.10000
# ...      ...                  ...                 ...
# 401506  2024            19.117638             0.10344
# 401507  2024            19.117638             0.10344
# 401508  2024            19.117638             0.10344
# 401509  2024            19.117638             0.10344
# 401510  2024            19.117638             0.10344
#
# [401511 rows x 11 columns]

# %%
X_train_end=X_train_enriquecido.drop(columns=['ctx-0'])
X_train_end
# Out:
#           station_id    year  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                  1  2021.0    1.0   1.0   0.0  0.043478  0.045290  0.050725
# 1                  1  2021.0    1.0   1.0   1.0  0.045290  0.050725  0.063406
# 2                  1  2021.0    1.0   1.0   2.0  0.050725  0.063406  0.119565
# 3                  1  2021.0    1.0   1.0   3.0  0.063406  0.119565  0.108696
# 4                  1  2021.0    1.0   1.0   4.0  0.119565  0.108696  0.108696
# ...              ...     ...    ...   ...   ...       ...       ...       ...
# 12949695          99  2023.0   12.0  31.0  19.0  0.320175  0.144737  0.208333
# 12949696          99  2023.0   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 12949697          99  2023.0   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 12949698          99  2023.0   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 12949699          99  2023.0   12.0  31.0  23.0  0.041667  0.016667  0.045833
#
#              ctx-1  temperature_2m (°C)  precipitation (mm)
# 0         0.063406             5.700000            0.000000
# 1         0.119565             6.500000            0.000000
# 2         0.108696             5.000000            0.000000
# 3         0.108696             4.700000            0.000000
# 4         0.108696             4.600000            0.000000
# ...            ...                  ...                 ...
# 12949695  0.150000            16.683865            0.064191
# 12949696  0.041667            16.683865            0.064191
# 12949697  0.016667            16.683865            0.064191
# 12949698  0.045833            16.683865            0.064191
# 12949699  0.000000            16.683865            0.064191
#
# [12949700 rows x 11 columns]

# %%
y_train_end=X_train_enriquecido['ctx-0']
y_train_end
# Out:
# 0           0.119565
# 1           0.108696
# 2           0.108696
# 3           0.108696
# 4           0.108696
#               ...
# 12949695    0.041667
# 12949696    0.016667
# 12949697    0.045833
# 12949698    0.000000
# 12949699    0.000000
# Name: ctx-0, Length: 12949700, dtype: float64

# %%
X_test_end=X_test_enriquecido

# %% [markdown]
# ## Save csvs

# %%
X_train_end.to_csv("X_train_end_year_2023.csv", index=False)
y_train_end.to_csv("y_train_end_year_2023.csv", index=False)
#X_test_enriquecido.to_csv("X_test_end_year.csv", index=False)

# %%
X_test_enriquecido.to_csv("X_test_end_year_2023.csv", index=False)

# %%
X_test_enriquecido
# Out:
#         station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# index
# 0                1      6    1     3  0.490942  0.378623  0.324275  0.311594
# 1                1      6    1     8  0.271739  0.311594  0.346014  0.394928
# 2                1      6    1    13  0.538043  0.650362  0.697464  0.721014
# 3                1      6    1    18  0.789855  0.800725  0.791667  0.807971
# 4                1      6    1    23  0.860507  0.871377  0.817029  0.793478
# ...            ...    ...  ...   ...       ...       ...       ...       ...
# 401506         496     12   31     2  0.865741  0.643519  0.597222  0.921296
# 401507         496     12   31     7  1.000000  0.388889  0.375000  0.407407
# 401508         496     12   31    12  0.310185  0.337963  0.402778  0.495370
# 401509         496     12   31    17  0.462963  0.564815  0.629630  0.583333
# 401510         496     12   31    22  0.467593  0.361111  0.546296  0.550926
#
#         year  temperature_2m (°C)  precipitation (mm)
# index
# 0       2024            16.200000             1.40000
# 1       2024            18.100000             0.00000
# 2       2024            22.200000             0.00000
# 3       2024            20.300000             0.80000
# 4       2024            16.600000             0.10000
# ...      ...                  ...                 ...
# 401506  2024            19.117638             0.10344
# 401507  2024            19.117638             0.10344
# 401508  2024            19.117638             0.10344
# 401509  2024            19.117638             0.10344
# 401510  2024            19.117638             0.10344
#
# [401511 rows x 11 columns]

# %% [markdown]
# # MODEL TESTING

# %% [markdown]
# ## LOAD CSV

# %%
X_train_end=pd.read_csv("X_train_end_year_2023.csv")
y_train_end=pd.read_csv("y_train_end_year_2023.csv")
X_test_end=pd.read_csv("X_test_end_year.csv")

# %%
X_train_end = X_train_end.drop(columns=['year'])
X_train_end
# Out:
#           station_id  month   day  hour     ctx-4     ctx-3     ctx-2  \
# 0                  1    1.0   1.0   0.0  0.043478  0.045290  0.050725
# 1                  1    1.0   1.0   1.0  0.045290  0.050725  0.063406
# 2                  1    1.0   1.0   2.0  0.050725  0.063406  0.119565
# 3                  1    1.0   1.0   3.0  0.063406  0.119565  0.108696
# 4                  1    1.0   1.0   4.0  0.119565  0.108696  0.108696
# ...              ...    ...   ...   ...       ...       ...       ...
# 12949695          99   12.0  31.0  19.0  0.320175  0.144737  0.208333
# 12949696          99   12.0  31.0  20.0  0.144737  0.208333  0.150000
# 12949697          99   12.0  31.0  21.0  0.208333  0.150000  0.041667
# 12949698          99   12.0  31.0  22.0  0.150000  0.041667  0.016667
# 12949699          99   12.0  31.0  23.0  0.041667  0.016667  0.045833
#
#              ctx-1  temperature_2m (°C)  precipitation (mm)
# 0         0.063406             5.700000            0.000000
# 1         0.119565             6.500000            0.000000
# 2         0.108696             5.000000            0.000000
# 3         0.108696             4.700000            0.000000
# 4         0.108696             4.600000            0.000000
# ...            ...                  ...                 ...
# 12949695  0.150000            16.683865            0.064191
# 12949696  0.041667            16.683865            0.064191
# 12949697  0.016667            16.683865            0.064191
# 12949698  0.045833            16.683865            0.064191
# 12949699  0.000000            16.683865            0.064191
#
# [12949700 rows x 10 columns]

# %%
X_test_end=X_test_end.drop(columns=['year'])

# %% [markdown]
# ## LINEAR REGRESSION

# %%
simple_model = LinearRegression()
simple_model.fit(X_train_end, y_train_end)
# Out:
# LinearRegression()

# %%
y_pred = simple_model.predict(X_test_end)

# %%
y_pred
# Out:
# array([[0.33750107],
#        [0.42506177],
#        [0.71064824],
#        ...,
#        [0.53649211],
#        [0.58520343],
#        [0.55565806]])

# %%
y_pred_end = y_pred.ravel()

# Crear el DataFrame utilizando el índice de X_test
df_output = pd.DataFrame({
    "percentage_docks_available": y_pred_end,
    "index": X_test_end.index
})


df_output
# Out:
#         percentage_docks_available   index
# 0                         0.337501       0
# 1                         0.425062       1
# 2                         0.710648       2
# 3                         0.784458       3
# 4                         0.763257       4
# ...                            ...     ...
# 401506                    0.965568  401506
# 401507                    0.433248  401507
# 401508                    0.536492  401508
# 401509                    0.585203  401509
# 401510                    0.555658  401510
#
# [401511 rows x 2 columns]

# %%
df_output.to_csv("submit_lr_1.csv", index=False)

# %% [markdown]
# ## RED NEURONAL

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import os
from google.colab import files
from sklearn.preprocessing import OneHotEncoder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# Escalar y aplicar PCA a X_train
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_end)

pca = PCA(n_components=0.95)  # Mantener el 95% de la varianza explicada
X_train_scaled = pca.fit_transform(X_train_scaled)

# Transformar X_test con el mismo scaler y PCA
X_test_scaled = scaler.transform(X_test_end)
X_test_pca = pca.transform(X_test_scaled)

# Crear y compilar el modelo de red neuronal
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1)
])

# Optimizador con decaimiento exponencial del learning rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=1000,
    decay_rate=0.9
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Callback: parar si no mejora tras 3 épocas
early_stop = EarlyStopping(monitor='loss', patience=2, restore_best_weights=True)

# Entrenar el modelo
model.fit(
    X_train_scaled,
    y_train_end,
    epochs=50,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)

# Predicción sobre X_test
y_pred = model.predict(X_test_pca)
print(y_pred)

# %% [markdown]
# #RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

model_RF = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
model_RF.fit(X_train_end, y_train_end)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=10, random_state=42)

# %%
y_pred = model_RF.predict(X_test_end)

# %%
y_pred_end = y_pred.ravel()

# Crear el DataFrame utilizando el índice de X_test
df_output = pd.DataFrame({
    "percentage_docks_available": y_pred_end,
    "index": X_test_end.index
})


df_output
df_output.to_csv("submit_RF.csv", index=False)

# %% [markdown]
# # XGBRegressor

# %% [markdown]
# ## 1

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.14.1)
# Downloading xgboost-3.0.0-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.26.2 xgboost-3.0.0

# %%
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

# Estandarización
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_end)
X_test_scaled = scaler.transform(X_test_end)

# Modelo optimizado
model_X = XGBRegressor(
    n_estimators=900,
    learning_rate=0.01,
    max_depth=25,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)
model_X.fit(X_train_scaled, y_train_end)

# %%
y_pred = model_X.predict(X_test_scaled
                         )

# %%
import pickle

# Guardar el modelo entrenado
with open("model_X1.pkl", "wb") as f:
    pickle.dump(model_X, f)

# %%
y_pred_end = y_pred.ravel()

df_output = pd.DataFrame({
    "percentage_docks_available": y_pred_end,
    "index": X_test_end.index
})


df_output
df_output.to_csv("submit_4.csv", index=False)

# %% [markdown]
# ## 2

# %%
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

# Estandarización
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_end)
X_test_scaled = scaler.transform(X_test_end)

# Entrenamiento del modelo
model_X = XGBRegressor(n_estimators=400, learning_rate=0.05, max_depth=12)
model_X.fit(X_train_scaled, y_train_end)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model_X.predict(X_test_scaled)

# %%
y_pred_end = y_pred.ravel()

# Crear el DataFrame utilizando el índice de X_test
df_output = pd.DataFrame({
    "percentage_docks_available": y_pred_end,
    "index": X_test_end.index
})


df_output
df_output.to_csv("submit_weath_2023-v2.csv", index=False)

# %%
import joblib

# Guardar solo el modelo
joblib.dump(model_X, "modelo_docks.pkl")
# Out:
# ['modelo_docks.pkl']

# %% [markdown]
# # lightgbm

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.14.1)
# Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 35.6 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
from lightgbm import LGBMRegressor

model = LGBMRegressor(
    n_estimators=700,
    learning_rate=0.05,
    max_depth=20,
    random_state=42
)
model.fit(X_train_scaled, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.088647 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1817
# [LightGBM] [Info] Number of data points in the train set: 8846081, number of used features: 11
# [LightGBM] [Info] Start training from score 0.626299
# LGBMRegressor(learning_rate=0.05, max_depth=20, n_estimators=700,
#               random_state=42)

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
y_pred_end = y_pred.ravel()

# Crear el DataFrame utilizando el índice de X_test
df_output = pd.DataFrame({
    "percentage_docks_available": y_pred_end,
    "index": X_test.index
})


df_output
df_output.to_csv("submit_v6.csv", index=False)
